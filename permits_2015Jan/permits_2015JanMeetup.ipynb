# %%
#==========================#
#  Import Data             #
#==========================#

import pandas as pd

july_df = pd.read_csv("Jul-2011.csv")
aug_df = pd.read_csv("Aug-2011.csv")

dlist = [july_df, aug_df]

full_dataframe = pd.concat(dlist)

full_dataframe.columns.values
# Out:
# array(['Street Number', 'Street Name', 'Postal Code', 'Ward',
#        'Plan Number', 'Lot Number', 'Contractor', 'Building Type',
#        'Municipality', 'Description', 'D.U.', 'Value', 'Sq. Ft.',
#        'Permit Number', 'Application Type', 'Permit Issued Date'], dtype=object)

# %%
#======================#
# 
#======================#

full_dataframe.groupby('Municipality').count()
# Out:
#                  Street Number  Street Name  Postal Code  Ward  Plan Number  \
# Municipality
# Cumberland                 273          273          240   273          131
# Gloucester                 240          240          219   240          188
# Goulbourn                  163          163          137   163          111
# Kanata                     192          192          171   191          171
# Nepean                     525          525          373   485          387
# Old Ottawa                 680          680          624   680          618
# Osgoode                     74           74           56    74           42
# Rideau                      28           28           14    28           15
# Rockcliffe Park              8            8            8     8            7
# Vanier                      15           15           14    15           14
# West Carleton               90           90           57    90           65
#
# ...
